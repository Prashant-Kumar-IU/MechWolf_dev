# %%
# Phase 3 Protocol Development Test Cell
# Step 1: Import and load experiment
from mechwolf.DataEntry.experimental_metadata import ExperimentalMetadataManager
from mechwolf.DataEntry.Phase3_ProtocolDev import launch_simple_builder

# Load your experiment (replace with your actual experiment file)
experiment = ExperimentalMetadataManager("test1.json")

protocol_builder =  launch_simple_builder(experiment)

print("🧪 Phase 3 Protocol Builder loaded successfully!")
print("Use the GUI tabs above to build your protocol step by step.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Phase 3 Protocol Development Test Cell
#       2 # Step 1: Import and load experiment
# ----> 3 from mechwolf.DataEntry.experimental_metadata import ExperimentalMetadataManager
#       4 from mechwolf.DataEntry.Phase3_ProtocolDev import launch_simple_builder
#       6 # Load your experiment (replace with your actual experiment file)
#
# File ~/MechWolf/mechwolf/__init__.py:29
#      26     nest_asyncio.apply()
#      28 # to avoid circular import
# ---> 29 from .core.apparatus import Apparatus
#      30 from .core.protocol import Protocol
#      31 from .components import *
#
# File ~/MechWolf/mechwolf/core/apparatus.py:12
#       9 from terminaltables import AsciiTable, GithubFlavoredMarkdownTable
#      11 from .. import _ureg
# ---> 12 from ..components import Component, Tube, Valve, Vessel
#      14 Connection = namedtuple("Connection", ["from_component", "to_component", "tube"])
#      17 class Apparatus(object):
#
# File ~/MechWolf/mechwolf/components/__init__.py:3
#       1 from mechwolf import _ureg
# ----> 3 from .contrib import *
#       4 from .stdlib import *
#
# File ~/MechWolf/mechwolf/components/contrib/__init__.py:6
#       4 from .fc203 import GilsonFC203
#       5 from .gsioc import GsiocInterface
# ----> 6 from .harvardpump import HarvardSyringePump
#       7 from .labjack import LabJack
#       8 from .varian import VarianPump
#
# File ~/MechWolf/mechwolf/components/contrib/harvardpump.py:3
#       1 import mechwolf as mw
# ----> 3 class HarvardSyringePump(mw.Pump):
#       4     """
#       5     A dual-channel infusion only Harvard syringe pump.
#       6
#    (...)     18     - `rate`: The current flow rate of the syringe pump (inherited from `mw.Pump`).
#      19     """
#      21     metadata = {
#      22         "author": [
#      23             {
#    (...)     60         "supported": True,
#      61     }
#
# AttributeError: partially initialized module 'mechwolf' has no attribute 'Pump' (most likely due to a circular import)

# %%
# Step 1: Import the old system
from mechwolf.DataEntry.experimental_metadata import ExperimentalMetadataManager
from mechwolf.DataEntry.Phase3_ProtocolDev import ProtocolDevGUI

# Step 2: Load or create an experiment
experiment = ExperimentalMetadataManager("test1.json")

#If you don't have an experiment file, create one:
#experiment = ExperimentalMetadataManager(filename="test_protocol_experiment.json", experiment_name="Old Protocol System Test")

# Step 3: Optional - Set up pumps dictionary (if you have actual pump objects)
#pumps = {
      #'pump_1': None,  # Replace with actual 
 # pump object if available
   #   'pump_2': None   # Replace with actual 
  #pump object if available
  #}

# Step 4: Launch the old Protocol Development GUI
protocol_gui = ProtocolDevGUI(experiment, protocol=None, pumps=pumps)

# Step 5: Display the old interface
protocol_gui.display()
