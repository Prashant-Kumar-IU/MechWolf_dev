# %%
# Phase 3 Protocol Development Test Cell
# Step 1: Import and load experiment
from mechwolf.DataEntry.experimental_metadata import ExperimentalMetadataManager
from mechwolf.DataEntry.Phase3_ProtocolDev import launch_simple_builder

# Load your experiment (replace with your actual experiment file)
experiment = ExperimentalMetadataManager("test1.json")

protocol_builder =  launch_simple_builder(experiment)

print("🧪 Phase 3 Protocol Builder loaded successfully!")
print("Use the GUI tabs above to build your protocol step by step.")
# Out:
# ...
# ❌ Error creating Tube 'tube_1': Tube.__init__() got an unexpected keyword argument 'name'
# ❌ Error creating Tube 'tube_2': Tube.__init__() got an unexpected keyword argument 'name'
# ❌ Error creating Tube 'tube_3': Tube.__init__() got an unexpected keyword argument 'name'
# ❌ Error creating HarvardSyringePump 'pump_1': module 'mechwolf' has no attribute 'HarvardSyringePump'
# ❌ Error creating HarvardSyringePump 'pump_2': module 'mechwolf' has no attribute 'HarvardSyringePump'
# ⚠️  Warning: Could not create connection pump_2 → tmixer_2
#     Missing: from_component 'pump_2'
# ⚠️ Warning: Could not load apparatus from metadata: Apparatus.add() missing 1 required positional argument: 'tube'
# ...
# 🧪 Phase 3 Protocol Builder loaded successfully!
# Use the GUI tabs above to build your protocol step by step.

# %%
# Step 1: Import the old system
from mechwolf.DataEntry.experimental_metadata import ExperimentalMetadataManager
from mechwolf.DataEntry.Phase3_ProtocolDev import ProtocolDevGUI

# Step 2: Load or create an experiment
experiment = ExperimentalMetadataManager("test1.json")

#If you don't have an experiment file, create one:
#experiment = ExperimentalMetadataManager(filename="test_protocol_experiment.json", experiment_name="Old Protocol System Test")

# Step 3: Optional - Set up pumps dictionary (if you have actual pump objects)
#pumps = {
      #'pump_1': None,  # Replace with actual 
 # pump object if available
   #   'pump_2': None   # Replace with actual 
  #pump object if available
  #}

# Step 4: Launch the old Protocol Development GUI
protocol_gui = ProtocolDevGUI(experiment, protocol=None, pumps=pumps)

# Step 5: Display the old interface
protocol_gui.display()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 20
#       6 experiment = ExperimentalMetadataManager("test1.json")
#       8 #If you don't have an experiment file, create one:
#       9 #experiment = ExperimentalMetadataManager(filename="test_protocol_experiment.json", experiment_name="Old Protocol System Test")
#      10
#    (...)     18
#      19 # Step 4: Launch the old Protocol Development GUI
# ---> 20 protocol_gui = ProtocolDevGUI(experiment, protocol=None, pumps=pumps)
#      22 # Step 5: Display the old interface
#      23 protocol_gui.display()
#
# NameError: name 'pumps' is not defined
